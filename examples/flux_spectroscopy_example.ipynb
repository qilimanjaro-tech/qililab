# %%
import flux_spectroscopy
# Out:
# [Qibo 0.1.7|INFO|2023-01-24 11:47:10]: Using numpy backend on /CPU:0
# [Qibo 0.1.7|WARNING|2023-01-24 11:47:10]: numpy backend uses `np.einsum` and supports CPU only. Consider installing the qibojit or qibotf backends for increased performance and to enable GPU acceleration.

# %%
flux_spectroscopy.run_and_plot(
    title="test",
    frequency_start=8.102e9,
    frequency_stop=8.1065e9,
    frequency_num=101,
    current_start=-0.009,
    current_stop=-0.012,
    current_num=11,
    attenuation_fixed=32,
    current_fixed=0,
)
# Out:
# Connected to: Rohde&Schwarz SGS100A (serial:1416.0505k02/113049, firmware:4.2.76.0-4.30.046.295) in 0.02s
# Connected to: Qblox SPI Rack (serial:None, firmware:{'device': 'v1.6 - May 10 2019 - mt', 'driver': {'version': '0.8.1', 'build': '13/12/2022-09:29:06', 'hash': '6c0c23ba', 'dirty': False}}) in 0.00s
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
